# %%
import numpy as np
import os
from pathlib import Path

from tcn import compiled_tcn
from sklearn.model_selection import train_test_split

# %%
TRAIN_DATA_FOLDER = Path('/Volumes/Seagate_drive/aFractionIndices1_05/interpolation-8days/train128')
TEST_DATA_FOLDER = Path('/Volumes/Seagate_drive/aFractionIndices1_05/interpolation-8days/test128')

TRAIN_DATA_LIST = os.listdir(TRAIN_DATA_FOLDER)
TEST_DATA_LIST = os.listdir(TEST_DATA_FOLDER)

# %%
file = np.load(os.path.join(TRAIN_DATA_FOLDER, TRAIN_DATA_LIST[53]))

# %%
file['x'].shape
# Out:
# (128, 34, 1, 1, 7)

# %%
file['y'].shape
# Out:
# (128, 1, 1, 2)

# %%
file['y']
# Out:
# array([[[[0.000000e+00, 4.425931e+06]]],
#
#
#        [[[4.000000e+00, 1.833674e+06]]],
#
#
#        [[[5.000000e+00, 1.836696e+06]]],
#
#
#        [[[0.000000e+00, 3.662030e+06]]],
#
#
#        [[[0.000000e+00, 3.662030e+06]]],
#
#
#        [[[0.000000e+00, 5.893895e+06]]],
#
#
#        [[[5.000000e+00, 4.690108e+06]]],
#
#
#        [[[0.000000e+00, 1.829189e+06]]],
#
#
#        [[[0.000000e+00, 1.834363e+06]]],
#
#
#        [[[0.000000e+00, 6.320100e+04]]],
#
#
#        [[[0.000000e+00, 1.507692e+06]]],
#
#
#        [[[0.000000e+00, 1.507692e+06]]],
#
#
#        [[[0.000000e+00, 3.662030e+06]]],
#
#
#        [[[0.000000e+00, 5.893895e+06]]],
#
#
#        [[[5.000000e+00, 4.690108e+06]]],
#
#
#        [[[5.000000e+00, 1.834427e+06]]],
#
#
#        [[[0.000000e+00, 1.829189e+06]]],
#
#
#        [[[0.000000e+00, 4.227288e+06]]],
#
#
#        [[[0.000000e+00, 1.834363e+06]]],
#
#
#        [[[0.000000e+00, 5.844737e+06]]],
#
#
#        [[[0.000000e+00, 1.507692e+06]]],
#
#
# ...

# %%
def data_generator():

# %%
data_generator()
